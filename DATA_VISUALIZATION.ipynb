# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame(np.random.rand(10,4),index=pd.date_range('1/1/2000',periods=10),columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.328964  0.961803  0.901064  0.219520
# 2000-01-02  0.315880  0.750814  0.669124  0.643379
# 2000-01-03  0.747416  0.702382  0.803548  0.677830
# 2000-01-04  0.964216  0.012947  0.201650  0.445661
# 2000-01-05  0.838459  0.326860  0.452319  0.369062
# 2000-01-06  0.430071  0.107562  0.052842  0.162956
# 2000-01-07  0.400503  0.166473  0.751225  0.161054
# 2000-01-08  0.851328  0.086947  0.713139  0.097362
# 2000-01-09  0.358031  0.241732  0.088060  0.148575
# 2000-01-10  0.187809  0.733900  0.867238  0.820338

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc6c626b390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6c6c3b2d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc6c6ebac50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6c674f150>]],
#       dtype=object)

# %%
df.plot()

# %%
df.plot(kind='scatter',x='A',y='D')

# %%
df.plot(kind='bar')

# %%
df.plot.bar(stacked=True)

# %%
df.plot.pie(x='A',y='C')

# %%
df.plot.box()

# %%
df.plot.area()
